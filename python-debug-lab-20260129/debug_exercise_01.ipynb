# %%
#Este programa pergunta dados do utilizador.

print(f"Olá utilizador!")
print("\n")
nome = input("Qual é o teu primeiro nome? ")
idade = int(input("Qual é a tua idade? "))
peso = int(input("Qual é o teu peso em kg? "))
print("\n")
print(f"Olá, {nome} \n{type(nome)}") # Converter todos os prints para f-string
print("\n")
print(f"Tens, {idade} anos \n{type(idade)}")
print("\n")
print(f"Pesas, {peso} kg \n{type(peso)}")
print("\n")
print("Programa terminado")
# Out:
# Olá utilizador!
#
#
# Qual é o teu primeiro nome? Rui
# Qual é a tua idade? 52
# Qual é o teu peso em kg? 90
#
#
# Olá, Rui
# <class 'str'>
#
#
# Tens, 52 anos
# <class 'int'>
#
#
# Pesas, 90 kg
# <class 'int'>
#
#
# Programa terminado
