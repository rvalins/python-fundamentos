# %% [markdown]
# <a href="https://colab.research.google.com/github/APata7/python-fundamentos/blob/corre%C3%A7%C3%A3o-exerc%C3%ADcio/python-debug-lab-20260129/debug_exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Este programa pergunta dados do utilizador.

nome = input("Qual é o teu nome? ")
idade = int(input("Qual é a tua idade? "))
peso = float(input("Qual é o teu peso em kg? "))

print(f"Olá {nome}")
print(f"Tens {idade} anos")
print(f"Pesas {peso} kg")

print("Programa terminado")
